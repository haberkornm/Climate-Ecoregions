# %%
import pandas as pd
import rasterio
from rasterio.warp import transform
import numpy as np
import mercantile
import requests
from tqdm import tqdm
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
import multiprocessing as mp
from shapely.geometry import Point
import math

# %% [markdown]
# # Downloading DEM tiles

# %%
BASE_DIR = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data")

RAW_DIR = BASE_DIR / "climate_files"        # raw data + DEM cache
WORK_DIR = BASE_DIR / "working_data"        # processed data
DOWNLOAD_DIR = RAW_DIR / "dem_tiles"        # DEM tile cache
INPUT_PKL = WORK_DIR / "clean_labeled_climate_data.pkl"       # your input DataFrame
OUTPUT_PKL = WORK_DIR / "clean_labeled_climate_data_elev.pkl" # output with elevation
ZOOM_LEVEL = 12                             # 30 m resolution
MAX_DOWNLOAD_THREADS = 8                    # concurrent tile downloads
MAX_SAMPLE_PROCESSES = mp.cpu_count()       # all CPU cores

# %%
RAW_DIR.mkdir(parents=True, exist_ok=True)
WORK_DIR.mkdir(parents=True, exist_ok=True)
DOWNLOAD_DIR.mkdir(parents=True, exist_ok=True)

# %%
df = pd.read_pickle(INPUT_PKL)
print(df.shape)
coords = ['latitude', 'longitude']
df[coords].head()
# Out:
# (470342, 125)
#     latitude  longitude
# 0  49.333333 -95.125000
# 1  49.333333 -95.083333
# 2  49.333333 -95.041667
# 3  49.333333 -95.000000
# 4  49.333333 -94.958333

# %%
def tile_for_point(lat, lon, zoom=ZOOM_LEVEL):
    return mercantile.tile(lon, lat, zoom)

tiles = [tile_for_point(lat, lon) for lat, lon in zip(df.latitude, df.longitude)]
df["tile_x"] = [t.x for t in tiles]
df["tile_y"] = [t.y for t in tiles]
df["tile_z"] = ZOOM_LEVEL
unique_tiles = sorted({(t.x, t.y, t.z) for t in tiles})
print(f"🗺️  Unique tiles required: {len(unique_tiles)}")
# Out:
# 🗺️  Unique tiles required: 139383

# %% [raw]
# # Download DEM tiles (multi-threaded)
# def fetch_tile(x, y, z, cache_dir=DOWNLOAD_DIR):
#     """Download a tile from AWS Terrain if not cached."""
#     url = f"https://s3.amazonaws.com/elevation-tiles-prod/geotiff/{z}/{x}/{y}.tif"
#     out_path = cache_dir / f"{z}_{x}_{y}.tif"
#     if not out_path.exists():
#         try:
#             r = requests.get(url, timeout=30)
#             r.raise_for_status()
#             out_path.write_bytes(r.content)
#         except Exception as e:
#             print(f"⚠️ Failed to fetch {url}: {e}")
#             return None
#     return out_path
#
# print("⬇️  Downloading required DEM tiles (if not cached)...")
# with ThreadPoolExecutor(max_workers=MAX_DOWNLOAD_THREADS) as ex:
#     list(tqdm(ex.map(lambda xy: fetch_tile(*xy), unique_tiles), total=len(unique_tiles)))

# %%
DEM_DIR = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\climate_files\dem_tiles")
OUTPUT_PKL = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\clean_labeled_climate_data_elev.pkl")
ZOOM_LEVEL = 12

# %%
print("Mapping coordinates to DEM tiles...")
tiles = [mercantile.tile(lon, lat, ZOOM_LEVEL) for lat, lon in zip(df.latitude, df.longitude)]
df["tile_x"] = [t.x for t in tiles]
df["tile_y"] = [t.y for t in tiles]
df["tile_z"] = ZOOM_LEVEL
unique_tiles = sorted({(t.x, t.y, t.z) for t in tiles})
print(f"Found {len(unique_tiles)} unique tiles in dataset.")
# Out:
# Mapping coordinates to DEM tiles...
# Found 139383 unique tiles in dataset.

# %%
tile_path = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\climate_files\dem_tiles\12_629_1417.tif")

with rasterio.open(tile_path) as src:
    print("Driver:", src.driver)
    print("CRS:", src.crs)
    print("Count (number of bands):", src.count)
    print("Dtype:", src.dtypes)
    print("NoData value:", src.nodata)
    print("Shape:", src.width, "×", src.height)
# Out:
# Driver: GTiff
# CRS: EPSG:3857
# Count (number of bands): 1
# Dtype: ('int16',)
# NoData value: -32768.0
# Shape: 512 × 512

# %% [markdown]
# # Processing DEM tiles for elevation

# %%
DEM_DIR = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\climate_files\dem_tiles")
INPUT_PKL = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\clean_labeled_climate_data.pkl")
OUTPUT_PKL = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\clean_labeled_climate_data_elev.pkl")

MAX_PROCESSES = 4
ZOOM = 12
CHUNK_SIZE = 5000  # max points per parallel batch inside a tile

# Load dataframe
df = pd.read_pickle(INPUT_PKL)
df["elevation"] = np.nan

# Compute tile_x, tile_y
def lonlat_to_tile(lon, lat, z):
    lat_rad = math.radians(lat)
    n = 2 ** z
    xtile = int((lon + 180.0) / 360.0 * n)
    ytile = int((1.0 - math.log(math.tan(lat_rad) + 1.0 / math.cos(lat_rad)) / math.pi) / 2.0 * n)
    return xtile, ytile

df["tile_x"], df["tile_y"] = zip(*df.apply(lambda r: lonlat_to_tile(r.longitude, r.latitude, ZOOM), axis=1))
df["tile_z"] = ZOOM

# Get unique tiles
unique_tiles = df[['tile_x','tile_y','tile_z']].drop_duplicates().itertuples(index=False, name=None)

# Function to sample a chunk of points in a tile
def sample_points(tile_path, coords, indices):
    # Reproject
    lon, lat = zip(*coords)
    xs, ys = transform("EPSG:4326", "EPSG:3857", lon, lat)
    coords_proj = list(zip(xs, ys))

    try:
        with rasterio.open(tile_path) as src:
            nodata = src.nodata
            results = []
            for idx, val in zip(indices, src.sample(coords_proj)):
                v = float(val[0])
                if v == nodata:
                    v = np.nan
                results.append((idx, v))
        return results
    except Exception as e:
        print(f"⚠️ Error reading {tile_path}: {e}")
        return []

# =========================================================
# PROCESS TILES SEQUENTIALLY
# =========================================================
for tile_key in tqdm(unique_tiles, desc="Processing tiles"):
    x, y, z = tile_key
    tile_path = DEM_DIR / f"{z}_{x}_{y}.tif"
    if not tile_path.exists():
        continue

    subset = df[(df.tile_x == x) & (df.tile_y == y)]
    if subset.empty:
        continue

    coords = list(zip(subset.longitude, subset.latitude))
    indices = subset.index.tolist()

    # Split into chunks for optional parallelization
    chunks = [(coords[i:i+CHUNK_SIZE], indices[i:i+CHUNK_SIZE]) for i in range(0, len(coords), CHUNK_SIZE)]

    results_tile = []
    if len(chunks) == 1:
        # Small tile → process sequentially
        results_tile.extend(sample_points(tile_path, chunks[0][0], chunks[0][1]))
    else:
        # Large tile → parallelize per chunk
        with ProcessPoolExecutor(max_workers=MAX_PROCESSES) as executor:
            futures = [executor.submit(sample_points, tile_path, c[0], c[1]) for c in chunks]
            for f in futures:
                results_tile.extend(f.result())

    # Assign elevations back to DataFrame
    for idx, elev in results_tile:
        df.at[idx, "elevation"] = elev

# Save final DataFrame
df.to_pickle(OUTPUT_PKL)
print(f"✅ Saved DataFrame with elevations: {OUTPUT_PKL}")
# Out:
# Processing tiles: 139383it [2:39:47, 14.54it/s]
# ✅ Saved DataFrame with elevations: C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\clean_labeled_climate_data_elev.pkl

# %% [markdown]
# # Data validation

# %%
df.elevation.value_counts()
# Out:
# elevation
#  0.0       2647
#  2.0       1184
#  1.0       1177
#  3.0       1037
#  5.0        938
#            ...
#  4079.0       1
# -74.0         1
# -27.0         1
# -32.0         1
# -38.0         1
# Name: count, Length: 3912, dtype: int64

# %%
df.elevation.max()
# Out:
# np.float64(4255.0)

# %%
df.elevation.min()
# Out:
# np.float64(-83.0)

# %%
df[df.elevation.isna()][['latitude', 'longitude', 'elevation']]
# Out:
#          latitude   longitude  elevation
# 81760   45.083333  -95.708333        NaN
# 81761   45.083333  -95.666667        NaN
# 82795   45.041667  -95.708333        NaN
# 82796   45.041667  -95.666667        NaN
# 160265  42.208333  -88.666667        NaN
# 160266  42.208333  -88.625000        NaN
# 161441  42.166667  -88.666667        NaN
# 161442  42.166667  -88.625000        NaN
# 290070  37.625000 -104.500000        NaN
# 290071  37.625000 -104.458333        NaN
# 290072  37.625000 -104.416667        NaN
# 291174  37.583333 -104.500000        NaN
# 291175  37.583333 -104.458333        NaN
# 291176  37.583333 -104.416667        NaN
# 342193  35.666667  -82.500000        NaN
# 342194  35.666667  -82.458333        NaN
# 343280  35.625000  -82.500000        NaN
# 343281  35.625000  -82.458333        NaN
# 371944  34.500000  -79.958333        NaN
# 371945  34.500000  -79.916667        NaN
# 372969  34.458333  -79.958333        NaN
# 372970  34.458333  -79.916667        NaN

# %%
na_elev = df[df.elevation.isna()].index.values
print(na_elev)
print(len(df[df.elevation.isna()]))
# Out:
# [ 81760  81761  82795  82796 160265 160266 161441 161442 290070 290071
#  290072 291174 291175 291176 342193 342194 343280 343281 371944 371945
#  372969 372970]
# 22

# %%
# Explaining why tiles returned na
from pyproj import Transformer

DEM_DIR = Path(r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\climate_files\dem_tiles")

# Find the 22 missing points
missing_df = df[df["elevation"].isna()].copy()
print(f"Found {len(missing_df)} points with missing elevation")

# Set up reprojection (lat/lon → EPSG:3857)
transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

# Track diagnostic results
diagnostics = []

for idx, row in missing_df.iterrows():
    z = int(row["tile_z"])
    x = int(row["tile_x"])
    y = int(row["tile_y"])
    lon, lat = row["longitude"], row["latitude"]

    tile_path = DEM_DIR / f"{z}_{x}_{y}.tif"

    if not tile_path.exists():
        diagnostics.append({
            "index": idx,
            "reason": "Tile missing",
            "tile_path": str(tile_path)
        })
        continue

    try:
        with rasterio.open(tile_path) as src:
            xs, ys = transformer.transform([lon], [lat])
            x_m, y_m = xs[0], ys[0]

            # Check if point is inside raster bounds
            inside = (
                src.bounds.left <= x_m <= src.bounds.right and
                src.bounds.bottom <= y_m <= src.bounds.top
            )

            if not inside:
                diagnostics.append({
                    "index": idx,
                    "reason": "Outside raster bounds",
                    "tile_path": str(tile_path)
                })
                continue

            # Sample raster value
            val = list(src.sample([(x_m, y_m)]))[0][0]

            if val == src.nodata:
                diagnostics.append({
                    "index": idx,
                    "reason": "NoData pixel",
                    "tile_path": str(tile_path)
                })
            else:
                diagnostics.append({
                    "index": idx,
                    "reason": f"Unexpected value: {val}",
                    "tile_path": str(tile_path)
                })

    except Exception as e:
        diagnostics.append({
            "index": idx,
            "reason": f"Error reading tile: {e}",
            "tile_path": str(tile_path)
        })

# Convert to DataFrame for easy review
diag_df = pd.DataFrame(diagnostics)
display(diag_df)

# Summarize results
print("\nSummary:")
print(diag_df["reason"].value_counts())
# Out:
# Found 22 points with missing elevation
#      index        reason                                          tile_path
# 0    81760  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 1    81761  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 2    82795  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 3    82796  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 4   160265  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 5   160266  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 6   161441  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 7   161442  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 8   290070  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 9   290071  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 10  290072  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 11  291174  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 12  291175  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 13  291176  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 14  342193  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 15  342194  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 16  343280  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 17  343281  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 18  371944  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 19  371945  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 20  372969  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# 21  372970  Tile missing  C:\Users\matta\Desktop\Documents\Python\Geoloc...
# Summary:
# reason
# Tile missing    22
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.scatter(df.longitude, df.latitude)
plt.scatter(df[df.index.isin(na_elev)].longitude, df[df.index.isin(na_elev)].longitude, color = 'red')
plt.show()

# %% [markdown]
# The coordinates of the 22 points that returned na values for elevation were bad so those rows will be dropped from the dataframe.

# %%
df.dropna(inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#    longitude   latitude   jan_tmin   feb_tmin  mar_tmin  apr_tmin  may_tmin  \
# 0 -95.125000  49.333333 -21.235899 -19.854500  -11.9746   -3.1587    4.6277
# 1 -95.083333  49.333333 -21.279900 -19.933199  -12.0637   -3.1952    4.7131
# 2 -95.041667  49.333333 -21.324699 -20.006300  -12.1446   -3.2326    4.8096
# 3 -95.000000  49.333333 -21.168699 -19.984699  -12.1437   -3.1702    5.0009
# 4 -94.958333  49.333333 -21.145699 -20.048500  -12.2071   -3.2110    5.0287
#
#     jun_tmin   jul_tmin   aug_tmin  ...              Level_1  \
# 0  11.043099  13.148000  12.008599  ...  5  NORTHERN FORESTS
# 1  11.207300  13.268300  12.234699  ...  5  NORTHERN FORESTS
# 2  11.348900  13.348800  12.448400  ...  5  NORTHERN FORESTS
# 3  11.497399  13.476299  12.646600  ...  5  NORTHERN FORESTS
# 4  11.568000  13.471100  12.694600  ...  5  NORTHERN FORESTS
#
#                   Level_2                             Level_3         Level_4  \
# 0  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands  49a  Peatlands
# 1  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands  49a  Peatlands
# 2  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands  49a  Peatlands
# 3  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands  49a  Peatlands
# 4  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands  49a  Peatlands
#
#                       ECO_NAME  climates_f  elevation  tile_x  tile_y  tile_z
# 0  Western Great Lakes forests         Dfb      332.0     965    1400      12
# 1  Western Great Lakes forests         Dfb      332.0     966    1400      12
# 2  Western Great Lakes forests         Dfb      328.0     966    1400      12
# 3  Western Great Lakes forests         Dfb      328.0     967    1400      12
# 4  Western Great Lakes forests         Dfb      325.0     967    1400      12
#
# [5 rows x 129 columns]

# %%
df.drop(columns = ['tile_x', 'tile_y', 'tile_z'], inplace = True)

# %%
plt.figure(figsize=(12, 6))
sc = plt.scatter(df["longitude"], df["latitude"], c=df["elevation"],
                 cmap="terrain", s=0.05, alpha=0.8)
plt.colorbar(sc, label="Elevation (m)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Elevation across the Lower 48 States")
plt.show()

# %% [markdown]
# # Saving dataframe

# %%
df.shape
# Out:
# (470320, 126)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'jan_tmin', 'feb_tmin', 'mar_tmin', 'apr_tmin',
#        'may_tmin', 'jun_tmin', 'jul_tmin', 'aug_tmin',
#        ...
#        'nov_vpdmin', 'dec_vpdmin', 'annual_vpdmin', 'Level_1', 'Level_2',
#        'Level_3', 'Level_4', 'ECO_NAME', 'climates_f', 'elevation'],
#       dtype='object', length=126)

# %%
OUTPUT_PKL
# Out:
# WindowsPath('C:/Users/matta/Desktop/Documents/Python/Geolocation/climate_data/working_data/clean_labeled_climate_data_elev.pkl')

# %%
# Save final DataFrame
df.to_pickle(OUTPUT_PKL)
print(f"✅ Saved DataFrame with elevations: {OUTPUT_PKL}")
# Out:
# ✅ Saved DataFrame with elevations: C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\clean_labeled_climate_data_elev.pkl

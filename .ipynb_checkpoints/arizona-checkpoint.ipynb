# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\climate_data_complete.parquet"

# %%
df = pd.read_parquet(path)
df.shape
# Out:
# (470320, 171)

# %%
df = pd.DataFrame(df[df.state == 'AZ'].reset_index(drop=True))

# %%
labels = ['Level_1', 'Level_2', 'Level_3', 'Level_4', 'ECO_NAME']

# %%
for i in labels:
    df[i] = df[i].astype('str')

# %%
for i in labels:
    print(df[i].value_counts())
    print()
# Out:
# Level_1
# 10  NORTH AMERICAN DESERTS         11040
# 13  TEMPERATE SIERRAS               3476
# 12  SOUTHERN SEMIARID HIGHLANDS     2115
# Name: count, dtype: int64
#
# Level_2
# 10.2  WARM DESERTS                     5879
# 10.1  COLD DESERTS                     5161
# 13.1  UPPER GILA MOUNTAINS             3476
# 12.1  WESTERN SIERRA MADRE PIEDMONT    2115
# Name: count, dtype: int64
#
# Level_3
# 10.2.2  Sonoran Desert                  4931
# 10.1.7  Arizona/New Mexico Plateau      4629
# 13.1.1  Arizona/New Mexico Mountains    3476
# 12.1.1  Madrean Archipelago             2115
# 10.2.1  Mojave Basin and Range           917
# 10.1.6  Colorado Plateaus                532
# 10.2.4  Chihuahuan Desert                 31
# Name: count, dtype: int64
#
# Level_4
# 81k  Arizona Upland/Eastern Sonoran Mountains          1319
# 81l  Arizona Upland/Eastern Sonoran Basins             1318
# 81j  Central Sonoran/Colorado Desert Basins            1272
# 23b  Madrean Lower Montane Woodlands                    906
# 79a  Apachian Valleys and Low Hills                     856
# 23c  Montane Conifer Forests                            819
# 23h  Lower Mogollon Transition                          807
# 22q  Dinetah Tablelands                                 619
# 22j  Semiarid Tablelands                                601
# 79b  Lower Madrean Woodlands                            571
# 22o  Northeast Arizona Shrub-Grasslands                 556
# 23e  Conifer Woodlands and Savannas                     489
# 22u  Kaibito/Moenkopi Sandy Plateaus                    469
# 79e  Madrean Basin Grasslands                           422
# 22z  Chino/Coconino Grasslands and Shrubsteppe          403
# 81n  Gila/Salt Intermediate Basins                      382
# 81i  Central Sonoran/Colorado Desert Mountains          378
# 22p  Little Colorado Valley/Painted Desert              320
# 22aa  Hualapai/Coconino Woodlands                       317
# 14a  Eastern Mojave Basins                              313
# 22t  Chinle Valley and Mesas                            281
# 14b  Eastern Mojave Low Ranges and Arid Footslopes      265
# 22x  Arizona Strip Plateaus                             251
# 23l  Mogollon Transition Conifer Forests                235
# 23j  Northern Woodlands and Sagebrush                   227
# 20c  Semiarid Benchlands and Canyonlands                221
# 20d  Arid Canyonlands                                   190
# 14e  Arid Valleys and Canyonlands                       182
# 22w  Grand Canyon                                       171
# 22v  Marble Platform                                    131
# 81g  Lower Colorado/Lower Gila River Valleys            130
# 14p  Lower Grand Canyon                                 127
# 20i  Cold Desert Sagebrush-Grasslands                   126
# 22r  Mesa Highlands                                     113
# 81o  Middle Gila/Salt River Floodplains                 108
# 22d  Virgin/Shivwits Woodland                           101
# 23d  Arizona/New Mexico Subalpine Forests                76
# 24c  Low Mountains and Bajadas                           72
# 79c  Madrean Pine-Oak and Mixed Conifer Forests          68
# 24a  Chihuahuan Basins and Playas                        67
# 20h  Sand Deserts                                        65
# 22s  Hopi Buttes                                         61
# 81d  Sand Hills/Sand Dunes                               47
# 81m  Sonoran Lava Fields                                 45
# 22y  Uinkaret/Aubrey Montane Conifer Forest              28
# 20e  Escarpments                                         25
# 23k  Sunset Crater Volcanics                             20
# 23i  Montane and Subalpine Grasslands                    20
# 22i  San Juan/Chaco Tablelands and Mesas                 14
# 14c  Eastern Mojave Mountain Woodland and Shrubland      14
# 79d  Willcox Playa                                       10
# 14f  Mojave Playas                                        3
# Name: count, dtype: int64
#
# ECO_NAME
# Colorado Plateau shrublands                 5190
# Sonoran desert                              4932
# Arizona Mountains forests                   3477
# Chihuahuan desert                           1761
# Mojave desert                                889
# Sierra Madre Occidental pine-oak forests     382
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import itertools
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# # Loading data

# %% [markdown]
# PCA+Kmeans or MiniBatchKMeans, PCA+UMAP,

# %%
path = r"C:\Users\matta\Desktop\Documents\Python\Geolocation\climate_data\working_data\labeled_climate_data.pkl"
df = pd.read_pickle(path)
df.shape
# Out:
# (481631, 122)

# %%
df.dropna(inplace = True)
df.reset_index(drop=True, inplace = True)
df.shape
# Out:
# (475432, 122)

# %%
df.Level_1.value_counts()
# Out:
# Level_1
# 8  EASTERN TEMPERATE FORESTS          147881
# 9  GREAT PLAINS                       138042
# 10  NORTH AMERICAN DESERTS             84970
# 6  NORTHWESTERN FORESTED MOUNTAINS     53015
# 5  NORTHERN FORESTS                    24590
# 11  MEDITERRANEAN CALIFORNIA            9600
# 13  TEMPERATE SIERRAS                   6136
# 7  MARINE WEST COAST FOREST             5707
# 12  SOUTHERN SEMIARID HIGHLANDS         2435
# 0  WATER                                1885
# 15  TROPICAL WET FORESTS                1171
# Name: count, dtype: int64

# %%
df = df[df.Level_1 != '0  WATER'].reset_index(drop=True)
df.shape
# Out:
# (473547, 122)

# %%
df.Level_1.unique()
# Out:
# array(['5  NORTHERN FORESTS', '7  MARINE WEST COAST FOREST',
#        '6  NORTHWESTERN FORESTED MOUNTAINS', '10  NORTH AMERICAN DESERTS',
#        '9  GREAT PLAINS', '8  EASTERN TEMPERATE FORESTS',
#        '11  MEDITERRANEAN CALIFORNIA', '13  TEMPERATE SIERRAS',
#        '12  SOUTHERN SEMIARID HIGHLANDS', '15  TROPICAL WET FORESTS'],
#       dtype=object)

# %%
df.Level_1.nunique()
# Out:
# 10

# %%
features = list(set(list(df.columns)) - set(['longitude', 'latitude', 'Level_1', 'Level_2', 'Level_3']))

# %%
feature_df = df[features]
scaler = StandardScaler()
scaled_df = scaler.fit_transform(feature_df)

# %%
scaled_df = pd.DataFrame(scaled_df)
scaled_df.columns = features
scaled_df[['longitude', 'latitude', 'Level_1', 'Level_2', 'Level_3']] = df[['longitude', 'latitude', 'Level_1', 'Level_2', 'Level_3']]
scaled_df.shape
# Out:
# (473547, 122)

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=0.85)   
X_pca = pca.fit_transform(scaled_df[features])
pca_df = pd.DataFrame(X_pca)
print(pca_df.shape)
pca_df.head()
# Out:
# (473547, 3)
#            0         1         2
# 0 -12.797958 -0.617557 -3.950647
# 1 -12.658393 -0.603536 -3.962532
# 2 -12.766973 -0.595062 -3.958539
# 3 -12.831695 -0.561866 -3.944222
# 4 -12.824347 -0.519016 -3.933657

# %%
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473547 entries, 0 to 473546
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       473547 non-null  float32
#  1   1       473547 non-null  float32
#  2   2       473547 non-null  float32
# dtypes: float32(3)
# memory usage: 5.4 MB

# %%
pca_df['longitude'], pca_df['latitude'], pca_df['Level_1'], pca_df['Level_2'], pca_df['Level_3'] = df['longitude'], df['latitude'], df['Level_1'], df['Level_2'], df['Level_3']
pca_df.shape
# Out:
# (473547, 8)

# %%
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473547 entries, 0 to 473546
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   0          473547 non-null  float32
#  1   1          473547 non-null  float32
#  2   2          473547 non-null  float32
#  3   longitude  473547 non-null  float64
#  4   latitude   473547 non-null  float64
#  5   Level_1    473547 non-null  object
#  6   Level_2    473547 non-null  object
#  7   Level_3    473547 non-null  object
# dtypes: float32(3), float64(2), object(3)
# memory usage: 23.5+ MB

# %%
plt.plot(pca.explained_variance_ratio_)
plt.title('PCA variance ratio')
plt.grid()
plt.show()

# %%
pca_df.head()
# Out:
#            0         1         2  longitude   latitude              Level_1  \
# 0 -12.797958 -0.617557 -3.950647 -95.125000  49.416667  5  NORTHERN FORESTS
# 1 -12.658393 -0.603536 -3.962532 -95.166667  49.375000  5  NORTHERN FORESTS
# 2 -12.766973 -0.595062 -3.958539 -95.125000  49.375000  5  NORTHERN FORESTS
# 3 -12.831695 -0.561866 -3.944222 -95.083333  49.375000  5  NORTHERN FORESTS
# 4 -12.824347 -0.519016 -3.933657 -95.041667  49.375000  5  NORTHERN FORESTS
#
#                   Level_2                             Level_3
# 0  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands
# 1  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands
# 2  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands
# 3  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands
# 4  5.2  MIXED WOOD SHIELD  5.2.2  Northern Minnesota Wetlands

# %%
pca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473547 entries, 0 to 473546
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   0          473547 non-null  float32
#  1   1          473547 non-null  float32
#  2   2          473547 non-null  float32
#  3   longitude  473547 non-null  float64
#  4   latitude   473547 non-null  float64
#  5   Level_1    473547 non-null  object
#  6   Level_2    473547 non-null  object
#  7   Level_3    473547 non-null  object
# dtypes: float32(3), float64(2), object(3)
# memory usage: 23.5+ MB

# %%
pca_df.columns
# Out:
# Index([0, 1, 2, 'longitude', 'latitude', 'Level_1', 'Level_2', 'Level_3'], dtype='object')

# %%
pairs = list(itertools.combinations([0,1,2], 2))
print(pairs)
# Out:
# [(0, 1), (0, 2), (1, 2)]

# %%
for i, j in pairs:
    plt.style.use("dark_background")
    plt.figure(figsize=(12,7.5))
    for k in pca_df.Level_1.unique():
        plt.scatter(pca_df[pca_df.Level_1 == k][i], pca_df[pca_df.Level_1 == k][j], s=1, label = k)
    plt.legend(
        bbox_to_anchor=(1.05, 0.5), 
        loc='center left')
    plt.grid()
    plt.title('Level 1 Ecoregions PCA')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # KMeans

# %% [markdown]
# ## Scaled data

# %%
df_labels = pd.DataFrame(scaled_df[['latitude', 'longitude', 'Level_1', 'Level_2', 'Level_3']])
X_scaled = pd.DataFrame(scaled_df.drop(columns = ['latitude', 'longitude', 'Level_1', 'Level_2', 'Level_3']))

# %%
df_labels.Level_1.value_counts()
# Out:
# Level_1
# 8  EASTERN TEMPERATE FORESTS          147881
# 9  GREAT PLAINS                       138042
# 10  NORTH AMERICAN DESERTS             84970
# 6  NORTHWESTERN FORESTED MOUNTAINS     53015
# 5  NORTHERN FORESTS                    24590
# 11  MEDITERRANEAN CALIFORNIA            9600
# 13  TEMPERATE SIERRAS                   6136
# 7  MARINE WEST COAST FOREST             5707
# 12  SOUTHERN SEMIARID HIGHLANDS         2435
# 15  TROPICAL WET FORESTS                1171
# Name: count, dtype: int64

# %%
kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)
df_labels['scaled_kmeans_label'] = clusters
for i in df_labels.Level_1.unique(): 
    print(i)
    print(df_labels[df_labels.Level_1 == i].scaled_kmeans_label.value_counts(normalize=True))
    print()
# Out:
# 5  NORTHERN FORESTS
# scaled_kmeans_label
# 9    0.898292
# 3    0.101708
# Name: proportion, dtype: float64
#
# 7  MARINE WEST COAST FOREST
# scaled_kmeans_label
# 5    0.930436
# 3    0.026809
# 1    0.023830
# 8    0.018749
# 6    0.000175
# Name: proportion, dtype: float64
#
# 6  NORTHWESTERN FORESTED MOUNTAINS
# scaled_kmeans_label
# 7    0.435028
# 0    0.267679
# 5    0.141884
# 6    0.074017
# 9    0.069452
# 1    0.010563
# 8    0.000962
# 3    0.000377
# 4    0.000038
# Name: proportion, dtype: float64
#
# 10  NORTH AMERICAN DESERTS
# scaled_kmeans_label
# 6    0.374050
# 0    0.277604
# 4    0.159009
# 1    0.136789
# 7    0.051960
# 2    0.000494
# 9    0.000071
# 5    0.000024
# Name: proportion, dtype: float64
#
# 9  GREAT PLAINS
# scaled_kmeans_label
# 0    0.295258
# 9    0.151555
# 1    0.126208
# 3    0.117638
# 2    0.113082
# 8    0.102223
# 6    0.086872
# 7    0.007164
# Name: proportion, dtype: float64
#
# 8  EASTERN TEMPERATE FORESTS
# scaled_kmeans_label
# 8    0.351025
# 3    0.293101
# 2    0.257051
# 9    0.098823
# Name: proportion, dtype: float64
#
# 11  MEDITERRANEAN CALIFORNIA
# scaled_kmeans_label
# 1    0.945208
# 6    0.031771
# 8    0.020521
# 5    0.001458
# 4    0.000833
# 7    0.000104
# 2    0.000104
# Name: proportion, dtype: float64
#
# 13  TEMPERATE SIERRAS
# scaled_kmeans_label
# 6    0.694752
# 1    0.238103
# 4    0.058996
# 7    0.008149
# Name: proportion, dtype: float64
#
# 12  SOUTHERN SEMIARID HIGHLANDS
# scaled_kmeans_label
# 1    0.764682
# 4    0.221355
# 6    0.013963
# Name: proportion, dtype: float64
#
# 15  TROPICAL WET FORESTS
# scaled_kmeans_label
# 2    1.0
# Name: proportion, dtype: float64

# %%
pca_df['scaled_kmeans_label'] = clusters

# %%
for i, j in pairs:
    plt.style.use("dark_background")
    plt.figure(figsize=(12,7.5))
    for k in pca_df.scaled_kmeans_label.unique():
        plt.scatter(pca_df[pca_df.scaled_kmeans_label == k][i], pca_df[pca_df.scaled_kmeans_label == k][j], s=1, label = k)
    plt.legend(
        bbox_to_anchor=(1.05, 0.5), 
        loc='center left')
    plt.grid()
    plt.title('Level 1 Ecoregions PCA')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## PCA data

# %%
X_pca = pd.DataFrame(pca_df[[0, 1, 2]])
kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_pca)
df_labels['pca_kmeans_label'] = clusters
for i in df_labels.Level_1.unique(): 
    print(i)
    print(df_labels[df_labels.Level_1 == i].pca_kmeans_label.value_counts(normalize=True))
    print()
# Out:
# 5  NORTHERN FORESTS
# pca_kmeans_label
# 3    0.837292
# 9    0.162708
# Name: proportion, dtype: float64
#
# 7  MARINE WEST COAST FOREST
# pca_kmeans_label
# 4    0.951638
# 2    0.017522
# 1    0.015595
# 9    0.015244
# Name: proportion, dtype: float64
#
# 6  NORTHWESTERN FORESTED MOUNTAINS
# pca_kmeans_label
# 0    0.510025
# 6    0.307705
# 4    0.118740
# 8    0.051250
# 2    0.008677
# 9    0.001867
# 3    0.001302
# 1    0.000415
# 7    0.000019
# Name: proportion, dtype: float64
#
# 10  NORTH AMERICAN DESERTS
# pca_kmeans_label
# 8    0.356679
# 6    0.330058
# 7    0.166447
# 2    0.128587
# 0    0.017724
# 5    0.000459
# 9    0.000024
# 4    0.000024
# Name: proportion, dtype: float64
#
# 9  GREAT PLAINS
# pca_kmeans_label
# 6    0.262587
# 3    0.171361
# 2    0.124962
# 9    0.123636
# 5    0.116225
# 1    0.102157
# 8    0.089031
# 0    0.010040
# Name: proportion, dtype: float64
#
# 8  EASTERN TEMPERATE FORESTS
# pca_kmeans_label
# 1    0.354129
# 9    0.290808
# 5    0.273747
# 3    0.081315
# Name: proportion, dtype: float64
#
# 11  MEDITERRANEAN CALIFORNIA
# pca_kmeans_label
# 2    0.925625
# 8    0.042188
# 1    0.027396
# 4    0.002500
# 7    0.002188
# 6    0.000104
# Name: proportion, dtype: float64
#
# 13  TEMPERATE SIERRAS
# pca_kmeans_label
# 8    0.644720
# 2    0.242992
# 6    0.056877
# 7    0.055411
# Name: proportion, dtype: float64
#
# 12  SOUTHERN SEMIARID HIGHLANDS
# pca_kmeans_label
# 2    0.681314
# 7    0.304723
# 8    0.012731
# 6    0.001232
# Name: proportion, dtype: float64
#
# 15  TROPICAL WET FORESTS
# pca_kmeans_label
# 5    1.0
# Name: proportion, dtype: float64

# %%
pca_df['pca_kmeans_label'] = clusters

# %%
for i, j in pairs:
    plt.style.use("dark_background")
    plt.figure(figsize=(12,7.5))
    for k in pca_df.pca_kmeans_label.unique():
        plt.scatter(pca_df[pca_df.pca_kmeans_label == k][i], pca_df[pca_df.pca_kmeans_label == k][j], s=1, label = k)
    plt.legend(
        bbox_to_anchor=(1.05, 0.5), 
        loc='center left')
    plt.grid()
    plt.title('Level 1 Ecoregions PCA')
    plt.tight_layout()
    plt.show()

# %%
for i in df_labels.scaled_kmeans_label.unique(): 
    print('scaled kmeans label:', i)
    print(df_labels[df_labels.scaled_kmeans_label == i].pca_kmeans_label.value_counts(normalize=True))
    print()
# Out:
# scaled kmeans label: 9
# pca_kmeans_label
# 3    0.873581
# 9    0.067344
# 0    0.059075
# Name: proportion, dtype: float64
#
# scaled kmeans label: 5
# pca_kmeans_label
# 4    0.883328
# 0    0.114570
# 6    0.001245
# 8    0.000778
# 9    0.000078
# Name: proportion, dtype: float64
#
# scaled kmeans label: 7
# pca_kmeans_label
# 0    0.708921
# 6    0.290869
# 3    0.000210
# Name: proportion, dtype: float64
#
# scaled kmeans label: 0
# pca_kmeans_label
# 6    0.858398
# 0    0.058737
# 3    0.034277
# 8    0.023607
# 9    0.020704
# 4    0.002674
# 1    0.001604
# Name: proportion, dtype: float64
#
# scaled kmeans label: 3
# pca_kmeans_label
# 9    0.939589
# 1    0.057953
# 3    0.001269
# 4    0.001076
# 0    0.000112
# Name: proportion, dtype: float64
#
# scaled kmeans label: 6
# pca_kmeans_label
# 8    0.897920
# 6    0.100034
# 2    0.001702
# 4    0.000325
# 1    0.000019
# Name: proportion, dtype: float64
#
# scaled kmeans label: 8
# pca_kmeans_label
# 1    0.949108
# 5    0.044835
# 2    0.003013
# 8    0.001507
# 4    0.001401
# 9    0.000136
# Name: proportion, dtype: float64
#
# scaled kmeans label: 1
# pca_kmeans_label
# 2    0.946984
# 7    0.031848
# 8    0.018487
# 1    0.002302
# 4    0.000380
# Name: proportion, dtype: float64
#
# scaled kmeans label: 4
# pca_kmeans_label
# 7    0.964152
# 2    0.035848
# Name: proportion, dtype: float64
#
# scaled kmeans label: 2
# pca_kmeans_label
# 5    0.998596
# 2    0.001131
# 1    0.000274
# Name: proportion, dtype: float64

# %% [markdown]
# # MDS

# %%
plt.hist(df.annual_meant, bins=50)
plt.show()

# %%
plt.hist(df.annual_precip, bins=50)
plt.show()

# %%
plt.figure(figsize=(10,6))

for cat in df["Level_1"].unique():
    subset = df[df["Level_1"] == cat]
    sns.kdeplot(
        subset["annual_precip"],
        label=cat, 
        fill=True,
        alpha=0.4
    )

plt.legend(title="Ecoregion Level 1", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()
